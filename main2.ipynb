# %%
# !python model_script.py --mode lm --epochs 2 --batch_size 128 --lr 0.0001 --model-name my_summarizer_model_trial_for_running
# Out:
# Vocabulary size: 5005
# ✅ Loading GloVe embeddings from D:/Desktop/neutral_summary_copy_by_towhid_002/neutral_summary_copy_by_towhid/glove.6B\glove.6B.200d.txt
# Training Language Model for 2 epochs...
# | Epoch: 001 | Train loss: 0.692 | Valid loss: 0.692 | time: 6.71s'
# | Epoch: 002 | Train loss: 9.212 | Valid loss: 9.210 | time: 3.22s'
# Saved model in ./outputs/models/lm/my_summarizer_model_trial_for_running.
# 2025-10-18 19:37:29.844216: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !python model_script.py --mode summ --lm-path ./outputs/models/lm/sentiment_agnostic_model_trial_for_running --epochs 50 --batch_size 128 --lr 0.0001 --model-name my_summarizer_model_trial_for_running
# Out:
# Vocabulary size: 5005
# Loading Language Model from ./outputs/models/lm/sentiment_agnostic_model_trial_for_running
# ✅ Loading GloVe embeddings from D:/Desktop/neutral_summary_copy_by_towhid_002/neutral_summary_copy_by_towhid/glove.6B\glove.6B.200d.txt
# Training Summarizer for 50 epochs...
# | Epoch: 001 | Train loss: 0.949 | Valid loss: 0.945 | time: 8.15s'
# Epoch 1/50 completed
# | Epoch: 002 | Train loss: 0.939 | Valid loss: 0.944 | time: 4.25s'
# Epoch 2/50 completed
# | Epoch: 003 | Train loss: 0.953 | Valid loss: 0.945 | time: 3.83s'
# Epoch 3/50 completed
# | Epoch: 004 | Train loss: 0.949 | Valid loss: 0.944 | time: 3.83s'
# Epoch 4/50 completed
# | Epoch: 005 | Train loss: 0.937 | Valid loss: 0.944 | time: 3.40s'
# Epoch 5/50 completed
# | Epoch: 006 | Train loss: 0.938 | Valid loss: 0.945 | time: 3.65s'
# Epoch 6/50 completed
# | Epoch: 007 | Train loss: 0.942 | Valid loss: 0.945 | time: 3.57s'
# Epoch 7/50 completed
# ...

# %%
# !python model_script.py --mode eval --model-name my_summarizer_model_trial_for_running --output-path ./outputs/summaries/generated_summaries_trial.csv
# Out:
# Vocabulary size: 5005
# Vocabulary size: 5005
# Loading summarizer from ./outputs/models/summ/my_summarizer_model_trial_for_running
# 2025-10-18 19:45:55.448725: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-18 19:46:02.410768: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# ...
# Loading data: 100%|██████████| 100/100 [00:00<00:00, 496.98item/s]
#
# ...
# Build vocabulary: 100%|██████████| 800/800 [00:00<00:00, 1175.84it/s]
#
# ...
# Loading data: 100%|██████████| 47/47 [00:01<00:00, 45.37item/s]
#
# ...
